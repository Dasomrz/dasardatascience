# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
import matplotlib.pyplot as plt

# %%
print("                ======soal nomer 1=======")
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['paskibra', 'PMR', 'Pramuka','futsal', 'volly', 'kesenian','rohis']
siswa = [5, 18, 30, 7, 16, 19, 12]
c = ['blue','cyan','black']
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 10")
plt.bar(jurusan, siswa, color = c)
plt.show()

print("")
print("                ======soal nomer 2=======")
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['paskibra', 'PMR', 'Pramuka','futsal', 'volly', 'kesenian','rohis']
siswa = [32, 34, 62, 51, 38, 41, 29]
c = ['blue','cyan','black']
plt.title("jumlah siswa yang mengikuti di setiap eskul eskul")
plt.bar(jurusan, siswa, color = c)
plt.show()

print("")
print("                ======soal nomer 3=======")
f1 = 7
f2 = 29
f3 = 15

v1 = 16
v2 = 10
v3 = 12

m = 287
tm = 45

hasil1 = (f1 + f2 + f3 + v1 + v2 + v3)
hasil2 = m - hasil1

print("hasil dari olahraga adalah : " +str (hasil1))
print("hasil dari mengikuti adalah : " +str (hasil2))
print("hasil dari tidak mengikuti adalah : " +str (tm))

ha1 = ((hasil1 / 332) * 10)
ha2 = ((hasil2 / 332) * 10)
ha3 = ((tm / 332) * 10)
print("hasil persentase olahraga adalah : " +str(ha1))
print("hasil persentase megikuti adalah : " +str(ha2))
print("hasil persentase tidak mengikuti adalah : " +str(ha3))

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['tidak mengikuti', 'olahraga', 'mengikuti',]
siswa = [26.81, 13.55, 59.63]
c = ['blue','cyan','black']
plt.title("soal nomer 4 diagram batang")
plt.bar(jurusan, siswa, color = c)
plt.show()

print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['tidak mengikuti', 'olahraga', 'mengikuti',]
siswa = [26.81, 13.55, 59.63]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("Diagram piechar")
plt.show()

print()
print("                ======soal nomer 4=======")
k10 = 17
k11 = 8
k12 = 20
index = 45
hi = 10

hasil10 = k10 / index
h10 = hasil10 * hi

hasil11 = k11 / index
h11 = hasil11 * hi

hasil12 = k12 / index
h12 = hasil12 * hi

print("maka hasil yang tidak mengikuti angkatan 10 adalah : " +str(h10))
print("maka hasil yang tidak mengikuti angkatan 10 adalah : " +str(h11))
print("maka hasil yang tidak mengikuti angkatan 10 adalah : " +str(h12))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['kelas 10', 'kelas 11', 'kelas 12']
siswa = [37.77, 17.77, 44.44]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("jumlah pesentaseu pichar")
plt.show()

print()
print("                ======soal nomer 5=======")
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['paskibra', 'PMR', 'Pramuka','futsal', 'volly', 'kesenian','rohis']
siswa = [5, 18, 30, 7, 16, 19, 12]
c = ['blue','cyan','black']
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 10")
plt.bar(jurusan, siswa, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['paskibra', 'PMR', 'Pramuka','futsal', 'volly', 'kesenian','rohis']
siswa = [21, 4, 8, 29, 10, 18, 10]
c = ['blue','cyan','black']
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 11")
plt.bar(jurusan, siswa, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['paskibra', 'PMR', 'Pramuka','futsal', 'volly', 'kesenian','rohis']
siswa = [6, 12, 24, 15, 12, 4, 7]
c = ['blue','cyan','black']
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 12")
plt.bar(jurusan, siswa, color = c)
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['paskibra', 'PMR', 'Pramuka','futsal', 'volly', 'kesenian','rohis']
siswa = [5, 18, 30, 7, 16, 19, 12]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 10")
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['paskibra', 'PMR', 'Pramuka','futsal', 'volly', 'kesenian','rohis']
siswa = [21, 4, 8, 29, 10, 18, 10]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 11")
plt.show()

print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['paskibra', 'PMR', 'Pramuka','futsal', 'volly', 'kesenian','rohis']
siswa = [6, 12, 24, 15, 12, 4, 7]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("jumlah siswa yang mengikuti ekstrakulikuler di kelas 12")
plt.show()
# Out:
#                 ======soal nomer 1=======
#                 ======soal nomer 2=======
#                 ======soal nomer 3=======
# hasil dari olahraga adalah : 89
# hasil dari mengikuti adalah : 198
# hasil dari tidak mengikuti adalah : 45
# hasil persentase olahraga adalah : 2.680722891566265
# hasil persentase megikuti adalah : 5.9638554216867465
# hasil persentase tidak mengikuti adalah : 1.355421686746988
#                 ======soal nomer 4=======
# maka hasil yang tidak mengikuti angkatan 10 adalah : 3.7777777777777777
# maka hasil yang tidak mengikuti angkatan 10 adalah : 1.777777777777778
# maka hasil yang tidak mengikuti angkatan 10 adalah : 4.444444444444445
#                 ======soal nomer 5=======
