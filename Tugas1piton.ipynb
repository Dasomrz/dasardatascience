# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
beras = 11400
minyak = 12700
ayam = 3400
telur =21800
popok =27000
sabun = 1800
anggur =3800
roti =8500
tisu =6400
mie =2200
diskon_1 = 90
diskon_2 = 85
diskon_3 = 80
diskon_4 = 75

print("            ===belanjaan tia==")
beras_tia = 4
ayam_tia = 20
telur_tia = 3
sabun_tia = 5
anggur_tia = 4
roti_tia = 2
mie_tia = 12
jb_tia = (beras_tia * beras) + (ayam_tia * ayam) + (telur_tia * telur) + (sabun_tia * sabun) + (anggur_tia * anggur) + (roti_tia *roti) + (mie_tia * mie)
jb_diskon_tia = (jb_tia /100) * diskon_2
print("maka jumlah belanjaan tia Rp." + str(jb_tia))

print("")
print("            ===belanjaan hana===")
minyak_hana = 2
ayam_hana = 5
telur_hana = 1.5
sabun_hana = 3  
anggur_hana = 8
roti_hana = 3
tisu_hana = 2
mie_hana = 20
jb_hana = (minyak_hana * minyak) + (ayam_hana * ayam) + (telur_hana * telur) + (sabun_hana * sabun) + (anggur_hana * anggur) + (roti_hana * roti) + (tisu_hana * tisu) + (mie_hana * mie)
jb_diskon_hana = (jb_hana/100) * diskon_1
print("makan jumlah belanjaan hana Rp." + str(jb_hana))

print("")
print("            ===belanjaan widia")
beras_widia = 1
minyak_widia = 1
telur_widia = 1
anggur_widia = 5
tisu_widia = 3
mie_widia = 16
jb_widia = (beras_widia * beras) + (minyak_widia * minyak) + (telur_widia * telur) + (anggur_widia * anggur) + (tisu_widia * tisu) + (mie_widia * mie)
print("maka jumlah belanjaan widia Rp." + str(jb_widia))

print("")
print("            ===belanjaan romi===")
minyak_romi = 3
telur_romi = 2
popok_romi = 4
sabun_romi = 8
mie_romi = 8
jb_romi = (minyak_romi * minyak) + (telur_romi * telur) + (popok_romi * popok) + (sabun_romi * sabun) + (mie_romi * mie)
jb_diskon_romi = (jb_romi / 100) *diskon_2
print("maka hasil belanjaan romi Rp." + str(jb_romi))

print("")
print("            ===belanjaan samsul")
ayam_samsul = 30
telur_samsul = 4
popok_samsul = 2
anggur_samsul = 7
tisu_samsul = 5
mie_samsul = 10
jb_samsul = (ayam_samsul * ayam) + (telur_samsul * telur) + (popok_samsul * popok) + (anggur_samsul * anggur) + (tisu_samsul * tisu) + (mie_samsul * mie)
jb_diskon_samsul = (jb_samsul / 100) * diskon_4
print("maka jumlah belanjaan samsul Rp." + str(jb_samsul))

print("")
print("            ===belanjaan Dimas===")
ayam_dimas = 5
popok_dimas = 5
sabun_dimas = 4
anggur_dimas = 3
roti_dimas = 5
mie_dimas = 6
jb_dimas = (ayam_dimas * (ayam * 10)) + (popok_dimas * popok) + (sabun_dimas * sabun) + (anggur_dimas * anggur) + (roti_dimas * roti) + (mie_dimas * mie)
jb_diskon_dimas = (jb_dimas / 100) * diskon_4
print("maka hasil belanjaan dimas Rp." + str(jb_dimas))
print()

print("===yang mendapatkan diskon")
print("maka jumlah belanjaan tia setelah mendapat diskon Rp." + str(jb_diskon_tia))
print("maka jumlah belanjaan hana setelah diskon Rp." + str(jb_diskon_hana))
print("maka hasil belanjaan romi setelah mendapatkan diskon Rp." + str(jb_diskon_romi))
print("maka hasil belanjaan samsul setelah mendapatkan diskon Rp." + str(jb_diskon_samsul))
print("maka hasil dari belajaan dimaas setelah mendapatkan diskon Rp." +str(jb_diskon_dimas))

print("")
print("===yang mendapat diskon 10%===")

max = [284475]
print("maka jumlah belanjaan paling besar setelah diskon adalah dimas RP." + str(max))

print("")
persen = {"hana" : "Rp.173880"}
print("maka yang mendapatkan diskon 10% adalah : " + str(persen))
# Out:
#             ===belanjaan tia==
# maka jumlah belanjaan tia Rp.246600
#
#             ===belanjaan hana===
# makan jumlah belanjaan hana Rp.193200.0
#
#             ===belanjaan widia
# maka jumlah belanjaan widia Rp.119300
#
#             ===belanjaan romi===
# maka hasil belanjaan romi Rp.221700
#
#             ===belanjaan samsul
# maka jumlah belanjaan samsul Rp.323800
#
#             ===belanjaan Dimas===
# maka hasil belanjaan dimas Rp.379300
#
# ===yang mendapatkan diskon
# maka jumlah belanjaan tia setelah mendapat diskon Rp.209610.0
# maka jumlah belanjaan hana setelah diskon Rp.173880.0
# maka hasil belanjaan romi setelah mendapatkan diskon Rp.188445.0
# maka hasil belanjaan samsul setelah mendapatkan diskon Rp.242850.0
# maka hasil dari belajaan dimaas setelah mendapatkan diskon Rp.284475.0
#
# ===yang mendapat diskon 10%===
# maka jumlah belanjaan paling besar setelah diskon adalah dimas RP.[284475]
#
# maka yang mendapatkan diskon 10% adalah : {'hana': 'Rp.173880'}
