# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
import matplotlib.pyplot as plt

# %%
print("     ======soal 1 ========")
print()
xis_k = 20 
log_k = 14
in_k = 28
namic_k = 42
plison_k = 18

jml_a = ((xis_k * 300000) + (xis_k * 75000))
print("maka gaji karyawan A-xis adalah : " +str(jml_a))

jml_b = ((log_k * 360000) + (log_k * 75000))
print("maka gaji karyawan B-log adalah : " +str(jml_b))

jml_c = ((in_k * 475000) + (in_k * 75000))
print("maka gaji karyawan C-in adalah : " +str(jml_c))

jml_d = ((namic_k * 580000) + (namic_k * 75000))
print("maka gaji karyawan D-namic adalah : " +str(jml_d))

jml_e = ((plison_k * 400000) + (plison_k * 75000))
print("maka gaji karyawan E-plison adalah : " +str(jml_e))
print()
print("     =====soal 2====")
print()
pajak = 0.03
laba_a = 32500000
laba_b = 31000000
laba_c = 42000000
laba_d = 51500000
laba_e = 27000000
aset_a = 0.08
aset_b = 0.04
aset_c = 0.12
aset_d = 0.11
aset_e = 0.03

hasil1 = (laba_a * pajak) + (aset_a * 280000000)
print("maka pajak dan hutang A-xis pertahun : " +str(hasil1))

hasil2 = (laba_b * pajak) + (aset_b * 310000000)
print("maka pajak dan hutang B-log pertahun : " +str(hasil2))

hasil3 = (laba_c * pajak) + (aset_c * 420000000)
print("maka pajak dan hutang C-in pertahun : " +str(hasil3))

hasil4 = (laba_d * pajak) + (aset_d * 550000000)
print("maka pajak dan hutang D-namic pertahun : " +str(hasil4))

hasil5 = (laba_e * pajak) + (aset_e * 340000000)
print("maka pajak dan hutang E-psilon pertahun : " +str(hasil5))

print()
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['A-xis', 'B-log', 'C-in','D-namic', 'E-psilon']
siswa = [23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0]
c = ['blue','cyan','black']
plt.title("Grafik batang dari soal 2")
plt.bar(jurusan, siswa, color = c)
plt.show()
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['A-xis', 'B-log', 'C-in','D-namic', 'E-psilon']
siswa = [23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("jumlah pesentaseu pichar")
plt.show()
print()
print("     =====soal 3 =======")
aset1 = 280000000
aset2 = 310000000
aset3 = 420000000
aset4 = 550000000
aset5 = 340000000

jum1 = aset1 * 2.5
print("maka hasil csr dari A-xis adalah : " +str(jum1))
jum2 = aset2 * 3.5
print("maka hasil csr dari B-log adalah : " +str(jum2))
jum3 = aset3 * 3.5
print("maka hasil csr dari C-in adalah : " +str(jum3))
jum4 = aset4 * 3.5
print("maka hasil csr dari D-namic adalah : " +str(jum4))
jum5 = aset5 * 3.5
print("maka hasil csr dari E-psilon adalah : " +str(jum5))
print()
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['A-xis', 'B-log', 'C-in','D-namic', 'E-psilon']
siswa = [700000000.0, 1085000000.0, 1470000000.0, 1925000000.0, 1190000000.0]
c = ['blue','cyan','black']
plt.title("Grafik batang dari soal 3")
plt.bar(jurusan, siswa, color = c)
plt.show()
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['A-xis', 'B-log', 'C-in','D-namic', 'E-psilon']
siswa = [700000000.0, 1085000000.0, 1470000000.0, 1925000000.0, 1190000000.0]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("jumlah pesentaseu pichar")
plt.show()
print()
print("     =====soal 4 =======")

hasila = laba_a * 12
print("maka hasil laba satu tahun di A-xis adalah : " +str(hasila))
hasilb = laba_b * 12
print("maka hasil laba satu tahun di B-log adalah : " +str(hasilb))
hasilc = laba_c * 12
print("maka hasil laba satu tahun di C-in adalah : " +str(hasilc))
hasild = laba_d * 12
print("maka hasil laba satu tahun di D-namic adalah : " +str(hasild))
hasile = laba_e * 12
print("maka hasil laba satu tahun di E-psilon adalah : " +str(hasile))
hasil_akhir = hasila + hasilb +hasilc + hasild + hasile
print("maka hasil laba satu tahun di keseluruhan adalah : " +str(hasil_akhir))
print()
print("     =====soal 5 =======")
print()
hasill = (laba_a * 12 ) - 0.025 * 280000000 - (7500000 * 12) - 23375000
print("maka penghasilan bersih pertahun adalah A-xis : " + str(hasill))
hasill_a = (laba_b * 12) - 0.035 * 310000000 - (6090000 * 12) - 13330000
print("maka penghasilan bersih pertahun adalah B-log : " + str(hasill_a))
hasill_b = (laba_c * 12) - 0.035 * 420000000 - (15400000 * 12) - 51660000
print("maka penghasilan bersih pertahun adalah B-log : " + str(hasill_b))
hasill_c = (laba_d * 12) - 0.035 * 550000000 - (27510000 * 12) - 62045000
print("maka penghasilan bersih pertahun adalah B-log : " + str(hasill_c))
hasill_d = (laba_e * 12) - 0.035 * 340000000 - (8550000 * 12) - 11010000
print("maka penghasilan bersih pertahun adalah B-log : " + str(hasill_d))
print()
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['A-xis', 'B-log', 'C-in','D-namic', 'E-psilon']
siswa = [269625000.0, 274740000.0, 252840000.0, 206585000.0, 198490000.0]
c = ['blue','cyan','black']
plt.title("Grafik batang dari soal 5")
plt.bar(jurusan, siswa, color = c)
plt.show()

print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['A-xis', 'B-log', 'C-in','D-namic', 'E-psilon']
siswa = [269625000.0, 274740000.0, 252840000.0, 206585000.0, 198490000.0]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("jumlah pesentaseu pichar")
plt.show()
# Out:
#      ======soal 1 ========
#
# maka gaji karyawan A-xis adalah : 7500000
# maka gaji karyawan B-log adalah : 6090000
# maka gaji karyawan C-in adalah : 15400000
# maka gaji karyawan D-namic adalah : 27510000
# maka gaji karyawan E-plison adalah : 8550000
#
#      =====soal 2====
#
# maka pajak dan hutang A-xis pertahun : 23375000.0
# maka pajak dan hutang B-log pertahun : 13330000.0
# maka pajak dan hutang C-in pertahun : 51660000.0
# maka pajak dan hutang D-namic pertahun : 62045000.0
# maka pajak dan hutang E-psilon pertahun : 11010000.0
#      =====soal 3 =======
# maka hasil csr dari A-xis adalah : 700000000.0
# maka hasil csr dari B-log adalah : 1085000000.0
# maka hasil csr dari C-in adalah : 1470000000.0
# maka hasil csr dari D-namic adalah : 1925000000.0
# maka hasil csr dari E-psilon adalah : 1190000000.0
#      =====soal 4 =======
# maka hasil laba satu tahun di A-xis adalah : 390000000
# maka hasil laba satu tahun di B-log adalah : 372000000
# ...
