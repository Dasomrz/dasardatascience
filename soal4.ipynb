# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
import matplotlib.pyplot as plt

# %%
burger = 24000
piza = 52000
dimsum = 30000
ekkado = 7500
milkshake = 10000
eskrim = 15000

print("     ======Soal nomer 1======")
burger1 = 6 
piza1 = 3
dimsum1 = 4
ekkado1 = 4
ms2 = 2
eskrim1 = 5

hasil = (burger1 * burger) + (piza1 * piza) + (dimsum1 * dimsum) + (ekkado1 * ekkado) + (ms2 * milkshake) + (eskrim1 * eskrim)
h1 = burger1 + piza1 + dimsum1 + ekkado1 + ms2 + eskrim1
print("maka jumlah semua total belanjaannya adalah : " +str(hasil))
print("maka seluruh makanan yang dibeli : " +str(h1))

print()
print("     ======Soal nomer 2======")
a1 = burger1 / h1
a2 = piza1 / h1
a3 = dimsum1 / h1
a4 = ekkado1 / h1
a5 = ms2 / h1
a6 = eskrim1 / h1

print("maka hasil persentase burger adalah : " +str(a1))
print("maka hasil persentase pizza adalah : " +str(a2))
print("maka hasil persentase dimsum adalah : " +str(a3))
print("maka hasil persentase ekkado adalah : " +str(a4))
print("maka hasil persentase milkshsake adalah : " +str(a5))
print("maka hasil persentase ice cream adalah : " +str(a6))

print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['burger', 'pizza', 'dimsum','ekkado','milkshake','eskrim']
siswa = [0.25, 0.125, 0.16666666666666666, 0.16666666666666666, 0.08333333333333333, 0.20833333333333334]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("jumlah pesentaseu pichar")
plt.show()

print()
print("     ======Soal nomer 3======")
print(" belanjaan ahmad")
burger_a = 4
piza_a = 2

jum_a = (0.70 * ((burger_a * 24000) + (piza_a * 52000))) + (7.5 * 2000) - 5000
print("maka jumlah yang harus dibayar : "+str(jum_a))
kem_a = 200000 - jum_a
print("maka kembalian ahmad adalah : "+str(kem_a))
print()

print(" belanjaan beni")
dimsum_b = 3
eskrim_b = 1
ms_b = 2

jum_b =  (0.70 * ((dimsum_b * 30000) + (eskrim_b * 15000) +(ms_b * 10000))) + (4 * 1800) - 5000
print("maka jumlah yang harus dibayar : "+str(jum_b))
kem_b = 150000 - jum_b
print("maka kembalian ahmad adalah : "+str(kem_b))
print()

print(" belanjaan citra")
eskrim_c = 3

jum_c = (eskrim_c * 15000) + (8 * 2000) - 5000
print("maka jumlah yang harus dibayar : "+str(jum_c))
kem_c = 60000 - jum_c
print("maka kembaliannya adalah : "+str(kem_c))
print()

print(" belanjaan dadang")
burger_d = 2
dimsum_d = 1

jum_d = (0.80 * ((burger_d * 24000) + (dimsum_d * 30000))) + (5 * 1800) - 5000
print("maka jumlah yang harus dibayar : "+str(jum_d))
kem_d = 100000 - jum_d
print("maka kembalian ahmad adalah : "+str(kem_d))
print()

print(" belanjaan epen")
ekkado_e = 4
eskrim_e = 1
piza_e = 1

jum_e = (0.70 * ((ekkado_e * 7500) + (eskrim_e * 15000) + (piza_e * 52000))) + (12 * 2200) - 5000
print("maka jumlah yang harus dibayar : "+str(jum_e))
kem_e = 100000 - jum_e
print("maka kembalian ahmad adalah : "+str(kem_e))
print()

print("     ======Soal 4=========")

ba_1 = 4
pa_1 = 2

hasil_a = (0.30 * ((ba_1 * 24000) + (pa_1 * 52000))) + 5000
print("maka hasil dari pototngan ahmad : " +str(hasil_a))

db = 3
esb = 1
mkb = 2

hasil_b = (0.30 * ((db * 30000) + (esb * 15000) + (mkb * 10000))) + 5000
print("maka hasil dari pototngan beni : " +str(hasil_b))

esc = 3

hasil_c = ( 0 *(eskrim_c * 15000)) + 5000

print("maka hasil dari pototngan citra : " +str(hasil_c))

bd = 2
dd = 1

hasil_d = (0.20 * ((bd * 24000) + (dd * 30000))) + 5000
print("maka hasil dari potongan dadang : " +str(hasil_d)) 

ee = 4
ese = 1
pe = 1

hasil_e = (0.30 * ((ee * 7500) + (ese * 15000) + (pe * 52000))) + 5000
print("maka hasil potongan epen : " +str(hasil_e))

seluruh = hasil_a + hasil_b + hasil_c + hasil_d + hasil_e
print("maka hasil dari semua potongan semuanya : " +str(seluruh))
print()
print("     ======soal 5========")

jarak = (7.5 * 2000) + (4 * 1800) + (8 * 2000) + (5 * 1800) + (12 * 2200)
print("maka total seluruh ongkir adalah : " +str(jarak))
# Out:
#      ======Soal nomer 1======
# maka jumlah semua total belanjaannya adalah : 545000
# maka seluruh makanan yang dibeli : 24
#
#      ======Soal nomer 2======
# maka hasil persentase burger adalah : 0.25
# maka hasil persentase pizza adalah : 0.125
# maka hasil persentase dimsum adalah : 0.16666666666666666
# maka hasil persentase ekkado adalah : 0.16666666666666666
# maka hasil persentase milkshsake adalah : 0.08333333333333333
# maka hasil persentase ice cream adalah : 0.20833333333333334
#      ======Soal nomer 3======
#  belanjaan ahmad
# maka jumlah yang harus dibayar : 150000.0
# maka kembalian ahmad adalah : 50000.0
#
#  belanjaan beni
# maka jumlah yang harus dibayar : 89700.0
# maka kembalian ahmad adalah : 60300.0
#
#  belanjaan citra
# maka jumlah yang harus dibayar : 56000
# maka kembaliannya adalah : 4000
#
#  belanjaan dadang
# maka jumlah yang harus dibayar : 66400.0
# maka kembalian ahmad adalah : 33600.0
#
#  belanjaan epen
# maka jumlah yang harus dibayar : 89300.0
# ...
