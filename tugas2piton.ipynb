# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
import matplotlib.pyplot as plt

# %%
s2a = 0
s2b = 1 
s2c = 4
s2d = 7
s2e = 5
s2f = 0

hasil_a = s2a + s2b + s2c + s2d + s2e + s2f
print("     ===Soal 1===")
print("maka hasil s2 adalah : " + str(hasil_a))

s1_a = 4
s1_b = 12
s1_c = 6
s1_d = 13
s1_e = 14
s1_f =  0

hasil_s1 = s1_a + s1_b + s1_c + s1_d + s1_e + s1_f
print("maka hasil s1 adalah : " + str(hasil_s1))
sma_a = 12
sma_b = 17
sma_c = 5
sma_d = 20
sma_e = 11
sma_f = 75

hasil_sma = sma_a + sma_b + sma_c + sma_d + sma_e + sma_f
print("maka hasil SMA adalah : " + str(hasil_sma))

smp_a = 5 
smp_b = 6
smp_c = 15
smp_d = 9
smp_e = 20
smp_f = 15

hasil_smp = smp_a + smp_b +smp_c + smp_d + smp_e + smp_f
print("maka hasil SMP adalah : " + str(hasil_smp))

sd_a = 1
sd_b = 8
sd_c = 0
sd_d = 19
sd_e = 10
sd_f = 1

hasil_sd = sd_a + sd_b +sd_c + sd_d + sd_e + sd_f
print("maka hasil SD adalah : " + str(hasil_sd))

tk_a = 2
tk_b = 14
tk_c = 3
tk_d = 10
tk_e = 0
tk_f = 1

hasil_tk = tk_a + tk_b +tk_c + tk_d + tk_e + tk_f
print("maka hasil yang tidak dikethaui : " + str(hasil_tk))

print()
print("     =====soal 2=====")

hasils2 = hasil_a * 0.25
hasils1 = hasil_s1 * 0.20
hasilsma = hasil_sma * 0.15
hasilsmp = hasil_smp * 0.10
hasilsd = hasil_sd * 0.05
hasiltk = hasil_tk * 0.03
print("maka hasil dari s2 adalah : " + str(hasils2))
print("maka hasil dari s1 adalah : " + str(hasils1))
print("maka hasil dari sma adalah : " + str(hasilsma))
print("maka hasil dari smp adalah : " + str(hasilsmp))
print("maka hasil dari sd adalah : " + str(hasilsd))
print("maka hasil dari tk adalah : " + str(hasiltk))

print()
print("     =====soal 3=====")

a_index = 0.25
b_index = 0.20
c_index = 0.15
d_index = 0.10
e_index = 0.05
f_index = 0.03

s2 = 0 * a_index
s1 = 4 * b_index
sma = 12 * c_index
smp = 5 * d_index
sd = 1 * e_index
tk = 2 * f_index
jos = s2 + s1 + sma + smp + sd + tk

print("maka hasil usia 70 s2 adalah : " + str(s2))
print("maka hasil usia 70 s1 adalah : " + str(s1))
print("maka hasil usia 70 sma adalah : " + str(sma))
print("maka hasil usia 70 smp adalah : " + str(smp))
print("maka hasil usia 70 sd adalah : " + str(sd))
print("maka hasil usia 70 wk adalah : " + str(tk))
print("maka hasil usia 70 keseluruhan : " + str(jos))
print()

s2_1 = 1 * a_index
s1_1 = 12 * b_index
sma_1 = 17 * c_index
smp_1 = 6 * d_index
sd_1 = 8 * e_index
tk_1 = 14 * f_index
hey = s2_1 + s1_1 + sma_1 + smp_1 + sd_1 + tk_1

print("maka hasil usia 60 s2 adalah : " + str(s2_1))
print("maka hasil usia 60 s1 adalah : " + str(s1_1))
print("maka hasil usia 60 sma adalah : " + str(sma_1))
print("maka hasil usia 60 smp adalah : " + str(smp_1))
print("maka hasil usia 60 sd adalah : " + str(sd_1))
print("maka hasil usia 60 wk adalah : " + str(tk_1))
print("maka hasil usia 60 keseluruhan : " + str(hey))
print()

s2_2 = 4 * a_index
s1_2 = 6 * b_index
sma_2 = 5 * c_index
smp_2 = 15 * d_index
sd_2 = 0 * e_index
tk_2 = 3 * f_index
jang = s2_2 + s1_2 + sma_2 + smp_2 + sd_2 + tk_2

print("maka hasil usia 50 s2 adalah : " + str(s2_2))
print("maka hasil usia 50 s1 adalah : " + str(s1_2))
print("maka hasil usia 50 sma adalah : " + str(sma_2))
print("maka hasil usia 50 smp adalah : " + str(smp_2))
print("maka hasil usia 50 sd adalah : " + str(sd_2))
print("maka hasil usia 50 wk adalah : " + str(tk_2))
print("maka hasil usia 50 keseluruhan : " + str(jang))
print()

s2_3 = 7 * a_index
s1_3 = 13 * b_index
sma_3 = 20 * c_index
smp_3 = 9 * d_index
sd_3 = 19 * e_index
tk_3 = 10 * f_index
godeg = s2_3 + s1_3 + sma_3 + smp_3 + sd_3 + tk_3

print("maka hasil usia 50 s2 adalah : " + str(s2_3))
print("maka hasil usia 50 s1 adalah : " + str(s1_3))
print("maka hasil usia 50 sma adalah : " + str(sma_3))
print("maka hasil usia 50 smp adalah : " + str(smp_3))
print("maka hasil usia 50 sd adalah : " + str(sd_3))
print("maka hasil usia 50 wk adalah : " + str(tk_3))
print("maka hasil usia 50 keseluruhan : " + str(godeg))
print()

s2_4 = 5 * a_index
s1_4 = 14 * b_index
sma_4 = 11 * c_index
smp_4 = 20 * d_index
sd_4 = 10 * e_index
tk_4 = 0 * f_index
kode = s2_4 + s1_4 + sma_4 + smp_4 + sd_4 + tk_4

print("maka hasil usia 50 s2 adalah : " + str(s2_4))
print("maka hasil usia 50 s1 adalah : " + str(s1_4))
print("maka hasil usia 50 sma adalah : " + str(sma_4))
print("maka hasil usia 50 smp adalah : " + str(smp_4))
print("maka hasil usia 50 sd adalah : " + str(sd_4))
print("maka hasil usia 50 wk adalah : " + str(tk_4))
print("maka hasil usia 50 keseluruhan : " + str(kode))
print()

s2_5 = 0 * a_index
s1_5 = 0 * b_index
sma_5 = 75 * c_index
smp_5 = 15 * d_index
sd_5 = 1 * e_index
tk_5 = 1 * f_index
dasom = s2_5 + s1_5 + sma_5 + smp_5 + sd_5 + tk_5

print("maka hasil usia 50 s2 adalah : " + str(s2_5))
print("maka hasil usia 50 s1 adalah : " + str(s1_5))
print("maka hasil usia 50 sma adalah : " + str(sma_5))
print("maka hasil usia 50 smp adalah : " + str(smp_5))
print("maka hasil usia 50 sd adalah : " + str(sd_5))
print("maka hasil usia 50 wk adalah : " + str(tk_5))
print("maka hasil usia 50 keseluruhan : " + str(dasom))

print()
print("     ====soal 4====")

persen = {"usia 70 tahun" : "24"}
print("indeks pendidikan paling kecil : " + str(persen))


print()
print("     ======soal 5====")
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['s2', 's1', 'sma','smp','sd','tk']
siswa = [17, 49, 140, 70, 39, 30]
c = ['blue','cyan','black']
plt.title("berdasarkan grafik batang pendidikan")
plt.bar(jurusan, siswa, color = c)
plt.show()

print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['s2', 's1', 'sma','smp','sd','tk']
siswa = [17, 49, 140, 70, 39, 30]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("berdasarkan grafik batang pendidikan")
plt.show()

print()
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1,])
jurusan = ['u70', 'u60', 'u50','u40','u30','u20']
siswa = [24, 58, 33, 78, 60, 92]
c = ['blue','cyan','black']
plt.title("berdasarkan grafik batang usia")
plt.bar(jurusan, siswa, color = c)
plt.show()

print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['u70', 'u60', 'u50','u40','u30','u20']
siswa = [24, 58, 33, 78, 60, 92]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.title("berdasarkan grafik batang usia")
plt.show()
# Out:
#      ===Soal 1===
# maka hasil s2 adalah : 17
# maka hasil s1 adalah : 49
# maka hasil SMA adalah : 140
# maka hasil SMP adalah : 70
# maka hasil SD adalah : 39
# maka hasil yang tidak dikethaui : 30
#
#      =====soal 2=====
# maka hasil dari s2 adalah : 4.25
# maka hasil dari s1 adalah : 9.8
# maka hasil dari sma adalah : 21.0
# maka hasil dari smp adalah : 7.0
# maka hasil dari sd adalah : 1.9500000000000002
# maka hasil dari tk adalah : 0.8999999999999999
#
#      =====soal 3=====
# maka hasil usia 70 s2 adalah : 0.0
# maka hasil usia 70 s1 adalah : 0.8
# maka hasil usia 70 sma adalah : 1.7999999999999998
# maka hasil usia 70 smp adalah : 0.5
# maka hasil usia 70 sd adalah : 0.05
# maka hasil usia 70 wk adalah : 0.06
# maka hasil usia 70 keseluruhan : 3.2099999999999995
#
# maka hasil usia 60 s2 adalah : 0.25
# maka hasil usia 60 s1 adalah : 2.4000000000000004
# maka hasil usia 60 sma adalah : 2.55
# maka hasil usia 60 smp adalah : 0.6000000000000001
# ...
